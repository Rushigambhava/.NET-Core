# %% [markdown]
# ### import Pandas

# %%
import pandas as pd

# %% [markdown]
# ### 1) Read csv or excel File

# %%
df = pd.read_csv ("BankChurners.csv")
df
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %% [markdown]
# ### 2) See the First 10 Rows

# %%
df.head(10)
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
# 5  713061558  Existing Customer            44      M                2
# 6  810347208  Existing Customer            51      M                4
# 7  818906208  Existing Customer            32      M                0
# 8  710930508  Existing Customer            37      M                3
# 9  719661558  Existing Customer            48      M                2
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# ...

# %% [markdown]
# ### 3) See the Last 10 Rows

# %%
df.tail(10)
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 10117  712503408  Existing Customer            57      M                2
# 10118  713755458  Attrited Customer            50      M                1
# 10119  716893683  Attrited Customer            55      F                3
# 10120  710841183  Existing Customer            54      M                1
# 10121  713899383  Existing Customer            56      F                1
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 10117        Graduate        Married    $80K - $120K          Blue
# ...

# %% [markdown]
# ### 4) Data type of each columns

# %%
df.dtypes
# Out:
# CLIENTNUM                                                                                                                               int64
# Attrition_Flag                                                                                                                         object
# Customer_Age                                                                                                                            int64
# Gender                                                                                                                                 object
# Dependent_count                                                                                                                         int64
# Education_Level                                                                                                                        object
# ...

# %% [markdown]
# ### 5) Display Summary Information

# %%
df.describe()
# Out:
#           CLIENTNUM  Customer_Age  Dependent_count  Months_on_book  \
# count  1.012700e+04  10127.000000     10127.000000    10127.000000
# mean   7.391776e+08     46.325960         2.346203       35.928409
# std    3.690378e+07      8.016814         1.298908        7.986416
# min    7.080821e+08     26.000000         0.000000       13.000000
# 25%    7.130368e+08     41.000000         1.000000       31.000000
# 50%    7.179264e+08     46.000000         2.000000       36.000000
# 75%    7.731435e+08     52.000000         3.000000       40.000000
# max    8.283431e+08     73.000000         5.000000       56.000000
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# count              10127.000000            10127.000000
# mean                   3.812580                2.341167
# std                    1.554408                1.010622
# min                    1.000000                0.000000
# 25%                    3.000000                2.000000
# ...

# %% [markdown]
# ### 6) Access a specific column

# %%
df['Gender']
# Out:
# 0        M
# 1        F
# 2        M
# 3        F
# 4        M
#         ..
# 10122    M
# 10123    M
# 10124    F
# 10125    M
# 10126    F
# Name: Gender, Length: 10127, dtype: object

# %% [markdown]
# ### 7) Access rows by their integer location

# %%
df.iloc[400:500]
# Out:
#      CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 400  788780958  Existing Customer            46      M                1
# 401  717354558  Attrited Customer            57      M                2
# 402  798473808  Existing Customer            48      M                3
# 403  712372158  Existing Customer            45      M                4
# 404  715192308  Existing Customer            48      M                2
# ..         ...                ...           ...    ...              ...
# 495  716920908  Existing Customer            52      M                4
# 496  708095133  Existing Customer            43      M                4
# 497  711195558  Existing Customer            59      M                1
# 498  772735758  Existing Customer            44      M                1
# 499  712024908  Existing Customer            56      F                1
#
#     Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %% [markdown]
# ### 8) Compute the Sum of Value

# %%
df['Months_on_book'].sum()
# Out:
# 363847

# %% [markdown]
# ### 9) Compute the Mean of Value

# %%
df['Months_on_book'].mean()
# Out:
# 35.928409203120374

# %% [markdown]
# ### 10) Count non-null value

# %%
(~df.isnull()).sum()
# Out:
# CLIENTNUM                                                                                                                             10127
# Attrition_Flag                                                                                                                        10127
# Customer_Age                                                                                                                          10127
# Gender                                                                                                                                10127
# Dependent_count                                                                                                                       10127
# Education_Level                                                                                                                       10127
# Marital_Status                                                                                                                        10127
# ...

# %% [markdown]
# ### 11) Find Maximum Values

# %%
df['Months_on_book'].max()
# Out:
# 56

# %% [markdown]
# ### 12) Find Minimum Values

# %%
df['Months_on_book'].min()
# Out:
# 13

# %% [markdown]
# ### 13) Find Number of Columns

# %%
df.shape[1]
# Out:
# 23

# %% [markdown]
# ### 14) Print the name of the columns

# %%
df.columns
# Out:
# Index(['CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender',
#        'Dependent_count', 'Education_Level', 'Marital_Status',
#        'Income_Category', 'Card_Category', 'Months_on_book',
#        'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'],
#       dtype='object')

# %% [markdown]
# ### 15) Print Unique data

# %%
df['Months_on_book'].nunique()
# Out:
# 44

# %% [markdown]
# ### 16) Calculate Average

# %%
print('Average:',df["Months_on_book"].mean())
# Out:
# Average: 35.928409203120374

# %% [markdown]
# ### 17) What is the number of observations in the dataset?

# %%
len(df)
# Out:
# 10127

# %% [markdown]
# ### 18) Most Frequent Months_on_book

# %%
df['Months_on_book'].value_counts().head(1)
# Out:
# Months_on_book
# 36    2463
# Name: count, dtype: int64

# %% [markdown]
# ### 19) dataset indexed

# %%
df.index
# Out:
# RangeIndex(start=0, stop=10127, step=1)

# %% [markdown]
# ### 20) Sort value by column Months_on_book.

# %%
df.sort_values(by='Months_on_book')
# Out:
#       CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 1683  789701658  Existing Customer            26      M                0
# 3757  710182383  Existing Customer            44      M                3
# 9897  710751033  Attrited Customer            31      F                1
# 6383  778671483  Existing Customer            33      F                3
# 6756  710098233  Existing Customer            28      F                0
# ...         ...                ...           ...    ...              ...
# 1330  822130683  Existing Customer            61      M                0
# 1625  713536158  Existing Customer            65      M                1
# 208   809164083  Existing Customer            63      M                1
# 3924  715548183  Existing Customer            65      M                1
# 2169  718181433  Existing Customer            65      F                0
#
#      Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %% [markdown]
# ### 21) Disply only this data where Months_on_book is more then 10.

# %%
df[df['Months_on_book']>10]
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %% [markdown]
# ### 22) Histogram chart for Months_on_book.

# %%
import matplotlib.pyplot as plt
df['Months_on_book'].hist()
plt.title('Months_on_book chart')
plt.show()

# %% [markdown]
# ### 23) top record

# %%
df.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# ...

# %% [markdown]
# ### 24) least accurance

# %%
counts = df['Credit_Limit'].value_counts()

least_common = counts[counts == counts.min()]
least_common
# Out:
# Credit_Limit
# 2036.0     1
# 14566.0    1
# 26690.0    1
# 10033.0    1
# 11238.0    1
#           ..
# 9183.0     1
# 29923.0    1
# 9551.0     1
# 11558.0    1
# 10388.0    1
# Name: count, Length: 4428, dtype: int64

# %% [markdown]
# ### 25) most frequent trestbps

# %%
df["Gender"].mode()[0]
# Out:
# 'F'
